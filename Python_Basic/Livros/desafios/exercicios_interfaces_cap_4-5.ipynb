# %%
import turtle
from multiprocessing.reduction import steal_handle
from jupyturtle import *
import math


def parellelogram(altura, largura, angule, angulo_oposto):

    for i in range(2):
        forward(largura)
        left(angule)
        forward(altura)
        left(angulo_oposto)

def rastro():
    penup()
    left(180)
    forward(50)
    left(90)
    forward(30)
    pendown()
    left(90)

def retangle(altura, largura):
    parellelogram(altura, largura, 90, 90)

def losangulo(comprimento, angule):
    angulo_oposto = 180 - angule
    parellelogram(comprimento, comprimento, angule, angulo_oposto)

make_turtle()

rastro()

retangle(50, 80)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 100,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 100,105 180,105 180,55 100,55 100,105" />'
#
# <g transform="rotate(-90.0,100.0,105.0) translate(100.0, 105.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>

# %%
make_turtle()
rastro()


losangulo(80, 50)
# Out:
# <svg width="300" height="150" style="fill:none; stroke-linecap:round;">
#     <rect width="100%" height="100%" fill="#F3F3F7" />
#
#
# <path stroke="#663399" stroke-width="2" d="M 150,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 100,75" />'
#
# <path stroke="#663399" stroke-width="2" d="M 100,105 180,105 231.4,43.7 151.4,43.7 100,105" />'
#
# <g transform="rotate(-90.0,100.0,105.0) translate(100.0, 105.0)">
#     <circle stroke="#63A375" stroke-width="2" fill="transparent" r="5.5" cx="0" cy="0"/>
#     <polygon points="0,12 2,9 -2,9" style="fill:#63A375;stroke:#63A375;stroke-width:2"/>
# </g>
#
# </svg>
